# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("cars analysis.csv")

# %% [markdown]
# **1 - descriptive statistics now we will aply differnnt tachniques to find the relation with price which faeture affects the price**

# %%
df.corr()
# Out:
#                    Unnamed: 0  symboling  normalized-losses  wheel-base  \
# Unnamed: 0           1.000000  -0.151621          -0.238306    0.129729
# symboling           -0.151621   1.000000           0.465190   -0.531954
# normalized-losses   -0.238306   0.465190           1.000000   -0.056518
# wheel-base           0.129729  -0.531954          -0.056518    1.000000
# length               0.170636  -0.357612           0.019209    0.874587
# width                0.052387  -0.232919           0.084195    0.795144
# height               0.255960  -0.541038          -0.370706    0.589435
# curb-weight          0.071962  -0.227691           0.097785    0.776386
# engine-size         -0.033930  -0.105790           0.110997    0.569329
# bore                 0.260077  -0.130083          -0.029266    0.488760
# stroke              -0.160844  -0.008689           0.054929    0.160944
# compression-ratio    0.150276  -0.178515          -0.114525    0.249786
# ...

# %% [markdown]
# **to find the correlatin bewteen feature to selecvt which is best for analysis**

# %%
df[["price","horsepower","engine-size",]].corr()
# Out:
#                 price  horsepower  engine-size
# price        1.000000    0.757917     0.861752
# horsepower   0.757917    1.000000     0.810713
# engine-size  0.861752    0.810713     1.000000

# %% [markdown]
# **Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines**

# %%
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 52259.27030750381)

# %%
sns.regplot(x="symboling", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# **as we can see that the graph is staright line with no positive and negative slope so we cant choose symboling for the analysis**

# %%
df[["highway-mpg","price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.690526
# price          -0.690526  1.000000

# %%
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48139.29062600823)

# %% [markdown]
# **as we can we see that we can take highway mpg for analysis however it has negative relation but it can take a part in analysis because highway mpg increase tha price decreases**

# %%
df[["stroke","price"]].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082095
# price   0.082095  1.000000

# %%
sns.regplot(x="stroke", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# **categorical variables These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots**

# %%
sns.boxplot(x="body-style", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
df[["body-style","price"]].corr()
# Out:
#        price
# price    1.0

# %% [markdown]
# **the above box plot have significant overlap not distinguish so we dont use this**

# %%
sns.boxplot(x = "aspiration",y = "price",data = df)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='price'>

# %%
sns.boxplot(x = "drive-wheels",y = "price",data=  df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  205.000000  205.000000         205.000000  205.000000  205.000000
# mean   102.000000    0.834146         122.000000   98.756585    0.836373
# std     59.322565    1.245307          31.681008    6.021776    0.059285
# min      0.000000   -2.000000          65.000000   86.600000    0.678039
# 25%     51.000000    0.000000         101.000000   94.500000    0.799135
# 50%    102.000000    1.000000         122.000000   97.000000    0.832292
# 75%    153.000000    2.000000         137.000000  102.400000    0.879865
# max    204.000000    3.000000         256.000000  120.900000    1.000000
#
#             width      height  curb-weight  engine-size        bore  \
# count  205.000000  205.000000   205.000000   205.000000  205.000000
# mean     0.911588   53.724878  2555.565854   126.907317    3.329751
# std      0.029671    2.443522   520.680204    41.642693    0.270844
# ...

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      205        205          205        205          205
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        168          116         96          120
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              205         205              205         205
# unique               2           7                7           8
# top              front         ohc             four        mpfi
# freq               202         148              159          94
#
#        horsepower_binned
# count                205
# unique                 3
# top                  low
# freq                 163

# %% [markdown]
# **value_counts**

# %% [markdown]
# **for more categorical analysis we can go for values counts**

# %%
df["drive-wheels"].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           120
# rwd            76
# 4wd             9

# %%
df["body-style"].value_counts().to_frame()
# Out:
#              body-style
# sedan                96
# hatchback            70
# wagon                25
# hardtop               8
# convertible           6

# %%
df["engine-location"].value_counts().to_frame()
# Out:
#        engine-location
# front              202
# rear                 3

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           120
# rwd            76
# 4wd             9

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           120
# rwd            76
# 4wd             9

# %%
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    120
# rwd                     76
# 4wd                      9

# %% [markdown]
# **Grouping**

# %%
df_group_one = df[['drive-wheels','price']]

# %%
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10570.569928
# 1          fwd   9310.818823
# 2          rwd  19671.422755

# %% [markdown]
# **we will do some group analysis**|

# %%
group = df[["drive-wheels","body-style","price"]]

# %%
group = group.groupby(["drive-wheels","body-style"], as_index = False).mean()

# %%
group.head(50)
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback  10405.064677
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9930.934363
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14278.269966
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# **when it si visulized on pivot it is much esier**

# %%
grouped_pivot = group.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN  10405.064677  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9930.934363
# rwd              23949.6  24202.714286  14278.269966  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# **to fill the missig values**

# %%
grouped_pivot = grouped_pivot.fillna(0) 
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000  10405.064677  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9930.934363
# rwd              23949.6  24202.714286  14278.269966  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grup = df[["body-style","price"]]

# %%
grup = grup.groupby(["body-style"],as_index = False).mean()

# %%
grup
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback  10050.289410
# 3        sedan  14433.658945
# 4        wagon  12371.960000

# %%
group1 = df[['body-style','drive-wheels','price']]

# %%
group1 = group1.groupby(["drive-wheels","body-style"], as_index = False).mean()

# %%
pivot = group1.pivot(index = "drive-wheels", columns = "body-style")

# %%
pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN  10405.064677  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9930.934363
# rwd              23949.6  24202.714286  14278.269966  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
pivot = pivot.fillna(0) 
pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000  10405.064677  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9930.934363
# rwd              23949.6  24202.714286  14278.269966  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# **correlation :a measure of the extent of interdependence between variables &
# causation :the relationship between cause and effect between two variables**

# %% [markdown]
# **correlation statistics find correlation coefficient and p values if coefficient  = +1 ok, = -1 ok but negative relation and =0 not ok when p <0.001 ok, p<0.05 modertae ok, p<0.01 weak**

# %%
from scipy import stats

# %%
pearson_coef,p_value  =stats.pearsonr(df["horsepower"],df["price"])

# %%
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7579169537498176  with a P-value of P = 1.6076703978131245e-39

# %%
b = person_coef,p_vale = stats.pearsonr(df["engine-size"],df["price"])

# %%
b
# Out:
# (0.8617522436859721, 9.669661923634776e-62)

# %%
c = pearson_coef,p_value = stats.pearsonr(df["highway-mpg"],df["price"])

# %%
c
# Out:
# (-0.6905257341183488, 2.23246740583743e-30)
